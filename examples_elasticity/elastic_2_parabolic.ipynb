# %%
from hans.input import Input

myProblem = Input("elastic_2_parabolic.yaml", None).getProblem()
myProblem.run(out_dir="data")
# Out:
#  /home/qd5728/Integration/lib/python3.12/site-packages/dtoolcore/__init__.py:14: UserWarning:pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# Reading input from elastic_2_parabolic.yaml...
# Checking I/O options...
# Checking discretization...
# Checking numerics options...
# Checking geometry...
# Checking material options...
# Checking boundary conditions...
# Sanity checks completed. Start simulation!
# ------------------------------------------------------------
# Step      	Timestep    	Time        	Epsilon
# #          0	1.000000e-12	0.000000e+00	inf
# current U: 0.0
#  /home/qd5728/Integration/hans/hans/integrate.py:624: RuntimeWarning:invalid value encountered in scalar divide
#  /home/qd5728/Integration/hans/hans/integrate.py:624: RuntimeWarning:divide by zero encountered in scalar divide
# #      10000	1.000000e-12	1.000000e-08	1.792782e+00
# current U: 0.01
# #      20000	1.000000e-12	2.000000e-08	8.805109e-01
# current U: 0.02
# #      30000	1.000000e-12	3.000000e-08	5.826055e-01
# current U: 0.03
# #      40000	1.000000e-12	4.000000e-08	4.349142e-01
# current U: 0.04
# #      50000	1.000000e-12	5.000000e-08	3.467169e-01
# current U: 0.05
# #      60000	1.000000e-12	6.000000e-08	2.880920e-01
# current U: 0.06
# #      70000	1.000000e-12	7.000000e-08	2.462989e-01
# current U: 0.07
# #      80000	1.000000e-12	8.000000e-08	2.149958e-01
# current U: 0.08
# #      90000	1.000000e-12	9.000000e-08	1.906709e-01
# current U: 0.09
# #     100000	1.000000e-12	1.000000e-07	1.712227e-01
# current U: 0.1
# #     110000	1.000000e-12	1.100000e-07	5.085720e-02
# current U: 0.1
# #     120000	1.000000e-12	1.200000e-07	3.547258e-02
# current U: 0.1
# #     130000	1.000000e-12	1.300000e-07	2.746664e-02
# current U: 0.1
# #     140000	1.000000e-12	1.400000e-07	2.231502e-02
# current U: 0.1
# #     150000	1.000000e-12	1.500000e-07	1.863772e-02
# current U: 0.1
# #     160000	1.000000e-12	1.600000e-07	1.584277e-02
# current U: 0.1
# #     170000	1.000000e-12	1.700000e-07	1.362654e-02
# current U: 0.1
# #     180000	1.000000e-12	1.800000e-07	1.181460e-02
# current U: 0.1
# #     190000	1.000000e-12	1.900000e-07	1.029848e-02
# current U: 0.1
# #     200000	1.000000e-12	2.000000e-07	9.006635e-03
# current U: 0.1
# #     210000	1.000000e-12	2.100000e-07	7.889707e-03
# current U: 0.1
# #     220000	1.000000e-12	2.200000e-07	6.912363e-03
# current U: 0.1
# #     230000	1.000000e-12	2.300000e-07	6.139347e-03
# current U: 0.1
# #     240000	1.000000e-12	2.400000e-07	5.458420e-03
# current U: 0.1
# #     250000	1.000000e-12	2.500000e-07	4.836318e-03
# current U: 0.1
# #     260000	1.000000e-12	2.600000e-07	4.277030e-03
# current U: 0.1
# #     270000	1.000000e-12	2.700000e-07	3.768336e-03
# current U: 0.1
# #     280000	1.000000e-12	2.800000e-07	3.311890e-03
# current U: 0.1
# #     290000	1.000000e-12	2.900000e-07	2.892641e-03
# current U: 0.1
# #     300000	1.000000e-12	3.000000e-07	2.509980e-03
# current U: 0.1
# #     310000	1.000000e-12	3.100000e-07	2.162090e-03
# current U: 0.1
# #     320000	1.000000e-12	3.200000e-07	1.840387e-03
# current U: 0.1
# #     330000	1.000000e-12	3.300000e-07	1.543632e-03
# current U: 0.1
# #     340000	1.000000e-12	3.400000e-07	1.269113e-03
# current U: 0.1
# #     350000	1.000000e-12	3.500000e-07	1.015762e-03
# current U: 0.1
# #     360000	1.000000e-12	3.600000e-07	7.845545e-04
# current U: 0.1
# #     370000	1.000000e-12	3.700000e-07	5.656063e-04
# current U: 0.1
# #     380000	1.000000e-12	3.800000e-07	3.637124e-04
# current U: 0.1
# #     390000	1.000000e-12	3.900000e-07	1.758169e-04
# current U: 0.1
# #     400000	1.000000e-12	4.000000e-07	4.908049e-08
#
# No convergence within  400000 steps. Stopping criterion: maximum number of iterations reached.
# Output written to: data/2025-08-01_142456_slider_elastic.nc
# Total wall clock time: 1:54:17 (Performance:  58.33 steps/s on 1 x 1 MPI grid)

# %%
from hans.cli.gradientAnalysis import gradientAnalysis
filepath = myProblem.outpath
filename = filepath.split('/')[-1]
gradientAnalysis(filename, r"_plot_output/gA_{}".format(filename))
# Out:
#  /home/qd5728/Integration/hans/hans/cli/gradientAnalysis.py:314: UserWarning:Attempting to set identical low and high ylims makes transformation singular; automatically expanding.

# %%
# continue running the problem
from hans.input import Input
restartFile = "data/2025-07-31_134800_slider_elastic.nc"
sameProblem = Input("elastic_2_parabolic.yaml", restartFile).getProblem()
sameProblem.run(out_dir="data")

# %%
from hans.cli.gradientAnalysis import gradientAnalysis
filepath = sameProblem.outpath
print(filepath)
filename = filepath.split('/')[-1]
gradientAnalysis(filename, r"_plot_output/gA_{}".format(filename))
